# %%
#Middle East and Russia analysis, Team 2 Divisadero 

#Importing packages 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Identify file 
file_all ='world_data_original.xlsx'

#Read file
world_data = pd.read_excel(file_all,
                          index_col = "Country Code")

world_data
# Out:
#                 Country Name Counter                  Hult Region  \
# Country Code
# AFG              Afghanistan      10         Middle East & Russia
# ALB                  Albania       9               Eastern Europe
# DZA                  Algeria       5  Northern Sub-Saharan Africa
# ASM           American Samoa       4          Australia & Oceania
# AND                  Andorra       9               Eastern Europe
# ...                      ...     ...                          ...
# PSE                West Bank      11            Arabian Peninsula
# WLD                    World   World                        World
# YEM                    Yemen      11            Arabian Peninsula
# ZMB                   Zambia       6            East/South Africa
# ZWE                 Zimbabwe       6            East/South Africa
#
#                     Cool Name  Access to electricity (% of population)  \
# Country Code
# AFG                    Mirage                                97.700000
# ...

# %%
#exploring data
print (world_data.describe())
# Out:
#        Access to electricity (% of population)  \
# count                               216.000000
# mean                                 85.649028
# std                                  24.729305
# min                                   9.300000
# 25%                                  80.662701
# 50%                                 100.000000
# 75%                                 100.000000
# max                                 100.000000
#
#        Access to electricity, rural (% of rural population)  \
# count                                         211.000000
# mean                                           81.067825
# std                                            31.664691
# min                                             1.658409
# 25%                                            71.868009
# 50%                                           100.000000
# 75%                                           100.000000
# max                                           100.000000
#
# ...

# %%
#exploting columns labels

print(world_data.columns)
# Out:
# Index(['Country Code', 'Country Name', 'Counter', 'Hult Region', 'Cool Name',
#        'Access to electricity (% of population)',
#        'Access to electricity, rural (% of rural population)',
#        'Access to electricity, urban (% of urban population)',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'Age dependency ratio (% of working-age population)',
#        'Age dependency ratio, old (% of working-age population)',
#        'Age dependency ratio, young (% of working-age population)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
#        'Armed forces personnel (% of total labor force)',
#        'Birth rate, crude (per 1,000 people)',
#        'Births attended by skilled health staff (% of total)',
#        'Death rate, crude (per 1,000 people)',
#        'Educational attainment, Doctoral or equivalent, population 25+, total (%) (cumulative)',
# ...

# %%
print (world_data.head(n=5))
# Out:
#   Country Code    Country Name Counter                  Hult Region  \
# 0          AFG     Afghanistan      10         Middle East & Russia
# 1          ALB         Albania       9               Eastern Europe
# 2          DZA         Algeria       5  Northern Sub-Saharan Africa
# 3          ASM  American Samoa       4          Australia & Oceania
# 4          AND         Andorra       9               Eastern Europe
#
#          Cool Name  Access to electricity (% of population)  \
# 0           Mirage                                     97.7
# 1  Skids & Mudflap                                    100.0
# 2        Bumblebee                                    100.0
# 3      Cliffhanger                                      NaN
# 4  Skids & Mudflap                                    100.0
#
#    Access to electricity, rural (% of rural population)  \
# 0                                          97.091973
# 1                                         100.000000
# ...

# %%
# count current observations
world_data.count()
# Out:
# Country Code                                217
# Counter                                     217
# Hult Region                                 217
# Cool Name                                   217
# Access to electricity (% of population)     216
#                                            ...
# Services, value added (% of GDP)            177
# Surface area (sq. km)                       215
# Tax revenue (% of GDP)                      128
# Urban population (% of total population)    214
# Urban population growth (annual %)          214
# Length: 67, dtype: int64

# %%
# Subsetting our region 

meru_data = world_data[world_data['Hult Region'] == 'Middle East & Russia']
print (meru_data)
#export to excel

meru_data.to_excel ('meru_data.xlsx')

meru_data = pd.read_excel (meru_data.xlsx,
                          index_col = 'Country Code')
# Out:
#               Country Name Counter           Hult Region Cool Name  \
# Country Code
# AFG            Afghanistan      10  Middle East & Russia    Mirage
# ARM                Armenia      10  Middle East & Russia    Mirage
# AZE             Azerbaijan      10  Middle East & Russia    Mirage
# BLR                Belarus      10  Middle East & Russia    Mirage
# BGR               Bulgaria      10  Middle East & Russia    Mirage
# GEO                Georgia      10  Middle East & Russia    Mirage
# IRN                   Iran      10  Middle East & Russia    Mirage
# MDA                Moldova      10  Middle East & Russia    Mirage
# PAK               Pakistan      10  Middle East & Russia    Mirage
# ROU                Romania      10  Middle East & Russia    Mirage
# RUS                 Russia      10  Middle East & Russia    Mirage
# TKM           Turkmenistan      10  Middle East & Russia    Mirage
# UKR                Ukraine      10  Middle East & Russia    Mirage
# ...
